# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from IPython.display import display, Markdown, Latex

# %%
# Load the dataset
df = pd.read_csv('Raw_COVID-19_Vaccination_Demographics_in_the_United_States_National_20250206 .csv')

# Replace blank strings with NaN
df.replace(r'^\s*$', np.nan, regex=True, inplace=True)

# For each column, if numeric, fill NaNs with median
for col in df.columns:
    if pd.api.types.is_numeric_dtype(df[col]):
        median_val = df[col].median()
        df[col].fillna(median_val, inplace=True)

# Optional: Save the cleaned dataframe
df.to_csv("Median_cleaned_dataset1.csv", index=False)



df.tail(10)
# Out:
# <ipython-input-16-e66be84ef769>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_val, inplace=True)
#              Date    Demographic_category Administered_Dose1  \
# 29876  12/13/2020  Race_eth_NHMultiracial                437
# 29877  12/13/2020               Sex_known             36,534
# 29878  12/13/2020       Race_eth_Hispanic              2,682
# 29879  12/13/2020          Ages_16-17_yrs                318
# 29880  12/13/2020     Race_eth_NHMult_Oth              1,231
# ...

# %%
C19_Demographic = pd.read_csv('C19_Demographic_Cleaned.csv')
C19_Demographic.isna().sum()
# Out:
# Date                                       0
# Demographic_category                       0
# Administered_Dose1                         0
# Administered_Dose1_pct_known               0
# Administered_Dose1_pct_US                  0
# Series_Complete_Yes                        0
# Administered_Dose1_pct_agegroup            0
# Series_Complete_Pop_pct_agegroup           0
# Series_Complete_Pop_Pct_known              0
# Series_Complete_Pop_Pct_US                 0
# Booster_Doses_Vax_pct_agegroup             0
# Booster_Doses_Pop_Pct_known                0
# Booster_Doses_Vax_Pct_US                   0
# Booster_Doses_Pop_Pct_known_Last14Days     0
# Booster_Doses_Yes                          0
# Booster_Doses_Yes_Last14Days               0
# Second_Booster_Vax_pct_agegroup            0
# Second_Booster_Pop_Pct_known               0
# Second_Booster_Pop_Pct_US                  0
# Second_Booster_Pop_Pct_known_Last14Days    0
# Second_Booster                             0
# ...

# %% [markdown]
# Now Cleaning 2nd Covid19_Vaccine Dataset.

# %%
# Load the dataset
df = pd.read_csv('Raw_COVID-19_Vaccinations_County.csv')

# Replace blank strings with NaN
df.replace(r'^\s*$', np.nan, regex=True, inplace=True)

# For each column, if numeric, fill NaNs with median
for col in df.columns:
    if pd.api.types.is_numeric_dtype(df[col]):
        median_val = df[col].median()
        df[col].fillna(median_val, inplace=True)

# Optional: Save the cleaned dataframe
df.to_csv("C19_Vaccine_Cleaned.csv", index=False)
# Out:
# <ipython-input-21-122767e3202d>:2: DtypeWarning: Columns (8,18,20,28,30,32,34,36,38,67,68,71,72,74,76,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Raw_COVID-19_Vaccinations_County.csv')
# <ipython-input-21-122767e3202d>:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(median_val, inplace=True)

# %%
C19_Vaccine = pd.read_csv('C19_Vaccine_Cleaned (1).csv')
print(C19_Vaccine.isna().sum())
# Out:
# <ipython-input-41-8fb3e4afba5a>:1: DtypeWarning: Columns (8,18,20,28,30,32,34,36,38,67,68,71,72,74,76,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   C19_Vaccine = pd.read_csv('C19_Vaccine_Cleaned (1).csv')
# Date                                0
# FIPS                                0
# MMWR_week                           0
# Recip_County                        0
# Recip_State                        81
#                                    ..
# Bivalent_Booster_12Plus_Pop_Pct     0
# Bivalent_Booster_18Plus             0
# Bivalent_Booster_18Plus_Pop_Pct     0
# Bivalent_Booster_65Plus             0
# Bivalent_Booster_65Plus_Pop_Pct     0
# Length: 80, dtype: int64

# %%
C19_Vaccine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171914 entries, 0 to 171913
# Data columns (total 80 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   Date                                     171914 non-null  object
#  1   FIPS                                     171914 non-null  object
#  2   MMWR_week                                171914 non-null  int64
#  3   Recip_County                             171914 non-null  object
#  4   Recip_State                              171833 non-null  object
#  5   Completeness_pct                         171914 non-null  float64
#  6   Administered_Dose1_Recip                 171914 non-null  object
#  7   Administered_Dose1_Pop_Pct               171914 non-null  float64
#  8   Administered_Dose1_Recip_5Plus           171914 non-null  object
#  9   Administered_Dose1_Recip_5PlusPop_Pct    171914 non-null  float64
# ...

# %%
C19_Vaccine = pd.read_csv('C19_Vaccine_Cleaned (1).csv')
C19_Vaccine.info()
# Out:
# <ipython-input-3-b1b8c0180a88>:1: DtypeWarning: Columns (8,18,20,28,30,32,34,36,38,67,68,71,72,74,76,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   C19_Vaccine = pd.read_csv('C19_Vaccine_Cleaned (1).csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171915 entries, 0 to 171914
# Data columns (total 80 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   Date                                     171914 non-null  object
#  1   FIPS                                     171914 non-null  object
#  2   MMWR_week                                171914 non-null  float64
#  3   Recip_County                             171914 non-null  object
#  4   Recip_State                              171833 non-null  object
#  5   Completeness_pct                         171914 non-null  float64
# ...

# %%
#Now lets clear 'FIPS' Column

Column_FIPS_UNK = C19_Vaccine[C19_Vaccine['FIPS']=='UNK']

Column_FIPS_UNK.shape # for getting idea  of total rows having 'FIPS == UNK '.

# Column_FIPS_UNK.index: Retrieves the index (row labels) of the rows in Column_FIPS_UNK. These are the row indices where FIPS == 'UNK'
# Covid19_Vaccine.drop(...): Removes rows from Covid19_Vaccine based on the provided indices.

C19_Vaccine_Cleaned = C19_Vaccine.drop(Column_FIPS_UNK.index)

C19_Vaccine_Cleaned.shape # verifying the successfully removel of rows having 'FIPS=UNK' with Column_FIPS_UNK.

C19_Vaccine_Cleaned.to_csv('C19_Vaccine_Cleaned_(1).csv',index=False)

# %%
#Now lets clear 'SVI_CTGY' Column

Column_SVI_BLK = C19_Vaccine[C19_Vaccine['SVI_CTGY'].isna()]

Column_SVI_BLK.shape # for getting idea  of total rows having 'SVI_CTGY == " "  '.

# Column_SVI_BLK.index: Retrieves the index (row labels) of the rows in Column_SVI_BLK. These are the row indices where SVI_CTGY == ' '


#C19_Vaccine_Cleaned.shape # verifying the successfully removel of rows having 'SVI_CTGY= " " ' with Column_SVI_BLK.
# Out:
# (2636, 80)

# %%
# this code block drops the rows having SVI_CTGY = " " .
# Covid19_Vaccine.drop(...): Removes rows from Covid19_Vaccine based on the provided indices.

C19_Vaccine_Cleaned = C19_Vaccine.drop(Column_SVI_BLK.index)

# %%
# veryfication of removal of all rows having SVI_CTGY == " ".
C19_Vaccine_Cleaned[C19_Vaccine_Cleaned['SVI_CTGY'].isna()]
# Out:
# Empty DataFrame
# ...

# %%
#Now lets clear 'SVI_CTGY' Column

Column_MTRO_BLK = C19_Vaccine[C19_Vaccine['Metro_status'].isna()]

Column_MTRO_BLK.shape # for getting idea  of total rows having 'Metro_Status == " "  '.

# Column_MTRO_BLK.index: Retrieves the index (row labels) of the rows in Column_SVI_BLK. These are the row indices where SVI_CTGY == ' '


#C19_Vaccine_Cleaned.shape # verifying the successfully removel of rows having 'SVI_CTGY= " " ' with Column_SVI_BLK.
# Out:
# (2636, 80)

# %%
# this code block drops the rows having Metro_status = " " .
# Covid19_Vaccine.drop(...): Removes rows from Covid19_Vaccine based on the provided indices.

C19_Vaccine_Cleaned = C19_Vaccine.drop(Column_MTRO_BLK.index)

# %%
# veryfication of removal of all rows having SVI_CTGY == " ".
C19_Vaccine_Cleaned[C19_Vaccine_Cleaned['Metro_status'].isna()]
# Out:
# Empty DataFrame
# ...

# %%
# Let's save the cleaned dataset.
C19_Vaccine_Cleaned.to_csv('C19_Vaccine_Cleaned_1.csv',index=False)
